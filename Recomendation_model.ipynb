# %%
import numpy as np
import pandas as pd

# %%
books =pd.read_csv('Books.csv')
users =pd.read_csv('Users.csv')
ratings =pd.read_csv('Ratings.csv')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9128\3729456920.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books =pd.read_csv('Books.csv')

# %%
books.sample(5)
# Out:
#               ISBN                                 Book-Title     Book-Author  \
# 85749   0812549449                            No Other Option    Marcus Wynne
# 37366   0425101339                                The Tracker       Tom Brown
# 173728  0385492154   The Girl in the Flammable Skirt: Stories    Aimee Bender
# 154106  0671582291  BLOODSTREAM : A Novel of Medical Suspense  Tess Gerritsen
# 46959   0898794048     How to Write and Sell Your First Novel   Oscar Collier
#
#        Year-Of-Publication                               Publisher  \
# 85749                 2002                               Tor Books
# 37366                 1996                Berkley Publishing Group
# 173728                1998  Bantam Doubleday Dell Publishing Group
# 154106                1998              Simon &amp; Schuster Audio
# 46959                 1990                         F &amp; W Pubns
#
#                                               Image-URL-S  \
# ...

# %%
users.sample(5)
# Out:
#         User-ID                              Location   Age
# 64634     64635                chicago, illinois, usa   NaN
# 145939   145940             kingston, ontario, canada  39.0
# 45250     45251  martin, western australia, australia  43.0
# 277346   277347  dordrecht, zuid holland, netherlands   NaN
# 38992     38993          torrington, connecticut, usa  22.0

# %%
ratings.sample(5)
# Out:
#         User-ID        ISBN  Book-Rating
# 613368   148263  0449005615           10
# 977528   235105  1566191807           10
# 912827   222296  1582343934            0
# 663033   160819  0671865706            5
# 178989    38802  0670030716            0

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (271360, 8)
# (1149780, 3)
# (278858, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
print(books.duplicated().sum())
print(users.duplicated().sum())
print(ratings.duplicated().sum())
# Out:
# 0
# 0
# 0

# %% [markdown]
# # Popularity Based Recommender System

# %%
ratings_with_name = ratings.merge(books,on='ISBN')
ratings_with_name.sample(5)
# Out:
#         User-ID        ISBN  Book-Rating  \
# 129195    32627  1568849036            8
# 192111    50225  0553260456            0
# 772273   208791  0672311402            5
# 442386   118434  0553250256            0
# 157742    38214  0060972122            0
#
#                                                Book-Title     Book-Author  \
# 129195  Upgrading &amp; Fixing PCs for Dummies (For Du...   Andy Rathbone
# 192111                                         Fire Watch   Connie Willis
# 772273         Peter Norton's Upgrading and Repairing PCs    Peter Norton
# 442386                                 Catcher in the Rye        Salinger
# 157742                        The Mysteries of Pittsburgh  Michael Chabon
#
#        Year-Of-Publication               Publisher  \
# 129195                1995   John Wiley &amp; Sons
# 192111                1998           Spectra Books
# 772273                1997  Macmillan Computer Pub
# 442386                1984            Bantam Books
# ...

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title').mean(numeric_only=True)['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
avg_rating_df
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241068                                Ã?Â?sterlich leben.    7.000000
# 241069                              Ã?Â?stlich der Berge.    2.666667
# 241070                                  Ã?Â?thique en toc    4.000000
#
# [241071 rows x 2 columns]

# %%
df = num_rating_df.merge(avg_rating_df , on='Book-Title')
df.head()
# Out:
#                                           Book-Title  num_ratings  avg_rating
# 0   A Light in the Storm: The Civil War Diary of ...            4        2.25
# 1                              Always Have Popsicles            1        0.00
# 2               Apple Magic (The Collector's series)            1        0.00
# 3   Ask Lily (Young Women of Faith: Lily Series, ...            1        8.00
# 4   Beyond IBM: Leadership Marketing and Finance ...            1        0.00

# %%
top_recom_df = df[df['num_ratings']>=250].sort_values('avg_rating' ,ascending=False)
top_recom_df = top_recom_df.merge(books , on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_ratings','avg_rating']]
top_recom_df = top_recom_df.reset_index(drop=True)
top_recom_df
# Out:
#                                             Book-Title        Book-Author  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)      J. K. Rowling
# 1         Harry Potter and the Goblet of Fire (Book 4)      J. K. Rowling
# 2       Harry Potter and the Sorcerer's Stone (Book 1)      J. K. Rowling
# 3    Harry Potter and the Order of the Phoenix (Boo...      J. K. Rowling
# 4     Harry Potter and the Chamber of Secrets (Book 2)      J. K. Rowling
# ..                                                 ...                ...
# 181       Vinegar Hill (Oprah's Book Club (Paperback))   A. Manette Ansay
# 182                                           Whispers        BELVA PLAIN
# 183                                  Presumed Innocent        Scott Turow
# 184                                       Isle of Dogs  Patricia Cornwell
# 185                                        Wild Animus       Rich Shapero
#
#                                            Image-URL-M  num_ratings  \
# ...

# %% [markdown]
# ## Collaborative Filtering Based Recommender System

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating']>200
padhe_likhe_users = x[x].index

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(padhe_likhe_users)]
filtered_rating
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1151      277427  0026217457            0
# 1152      277427  003008685X            8
# 1153      277427  0030615321            0
# 1154      277427  0060002050            0
# ...          ...         ...          ...
# 1029357   275970  1931868123            0
# 1029358   275970  3411086211           10
# 1029359   275970  3829021860            0
# 1029360   275970  4770019572            0
# 1029361   275970  9626340762            8
#
#                                                 Book-Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1151                    Vegetarian Times Complete Cookbook
# 1152                                              Pioneers
# 1153      Ask for May, Settle for June (A Doonesbury book)
# 1154                     On a Wicked Dawn (Cynster Novels)
# ...                                                    ...
# ...

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]
final_ratings
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1163      277427  0060930535            0
# 1165      277427  0060934417            0
# 1168      277427  0061009059            9
# 1174      277427  006440188X            0
# ...          ...         ...          ...
# 1029196   275970  1400031354            0
# 1029197   275970  1400031362            0
# 1029270   275970  1573229725            0
# 1029309   275970  1586210661            9
# 1029310   275970  1586212230            0
#
#                                                 Book-Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1163                         The Poisonwood Bible: A Novel
# 1165                                    Bel Canto: A Novel
# 1168     One for the Money (Stephanie Plum Novels (Pape...
# 1174                                     The Secret Garden
# ...                                                    ...
# ...

# %%
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

pt.fillna(0,inplace=True)
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (706, 706)

# %%
def recommend(book_name):
    index = np.where(pt.index == book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])), key = lambda x:x[1] , reverse= True)[1:5]

    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    
    return data

# %%
recommend('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg'],
#  ["The Handmaid's Tale",
#   'Margaret Atwood',
#   'http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)',
#   'ANNE RICE',
#   'http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg']]

# %%
import pickle
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))

# %%
pickle.dump(top_recom_df,open('popular.pkl','wb'))
